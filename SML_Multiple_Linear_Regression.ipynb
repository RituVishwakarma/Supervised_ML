# %% [markdown]
# Multiple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("/content/day.csv")
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
x=dataset[['season','yr','mnth','holiday','weekday','workingday','weathersit','temp','hum','windspeed']]
#x=dataset[['yr']]
y=dataset['cnt']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %% [markdown]
# Implementing Linear Regression

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model Equation

# %%
print("Intercept: ",mlr.intercept_)
print("Coeffficients:")
list(zip(x,mlr.coef_))
# Out:
# Intercept:  1623.3644238614788
# Coeffficients:
# [('season', 478.45032709006875),
#  ('yr', 2010.3572190553682),
#  ('mnth', -30.45322442201632),
#  ('holiday', -714.3163383837713),
#  ('weekday', 74.3608854762194),
#  ('workingday', 193.48656447555237),
#  ('weathersit', -682.6786836638659),
#  ('temp', 128.78551280646957),
#  ('hum', -7.9855637060863955),
#  ('windspeed', -47.54248489408246)]

# %% [markdown]
# Prediction on the test set

# %%
y_pred_mlr=mlr.predict(x_test)
#predicted values
print("Prediction for test set: {}".format(y_pred_mlr))
# Out:
# Prediction for test set: [3908.22931773 7438.21239636 3560.79933222 5620.52748259 4806.5494002
#  4191.84150359 5165.79684275 4287.79024889 5711.8576085  5709.19769186
#  6867.22024233 6634.45948298 4073.00338295 5866.60695139 2408.84161392
#  7347.33370897 5548.56823359 1555.12566184 5396.54516612 4749.25335168
#  7647.92093647 4653.32643759 6639.58446675 1524.67857052 3262.69431226
#  4675.07580483 7256.65994569 3968.04736819 6300.72983803 5049.77903043
#  7903.73459204 6237.32119597 4099.4501715  5227.39230679 2549.43596516
#  4036.38549392 4809.911325   6331.24527707 1322.10220121 3743.66835697
#  4633.81879843 3421.56420414 5953.13788982 6275.54363626 5038.20440306
#  7513.82409217 1552.53280895 4518.19964407 4855.25735689 2223.08200761
#  6632.04710187 4524.992562   5206.62243194 6738.13560381 3167.74203633
#  8049.79983043 4740.11424324 4037.35571801 2126.25713341 5684.04571106
#  4621.73406964 5015.26757988 2171.83048848 5335.87379415 4090.91974142
# ...

# %% [markdown]
# Actual values and predicted values

# %%
mlr_diff=pd.DataFrame({'Actual value':y_test,'Predicted value':y_pred_mlr})
mlr_diff.head()
# Out:
#      Actual value  Predicted value
# 184          6043      3908.229318
# 535          6211      7438.212396
# 299          2659      3560.799332
# 221          4780      5620.527483
# 152          4968      4806.549400
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_5, *['Actual value'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %% [markdown]
# Evaluating the model

# %%
from sklearn import metrics
meanAbErr=metrics.mean_absolute_error(y_test,y_pred_mlr)
meanSqrErr=metrics.mean_squared_error(y_test,y_pred_mlr)
rootMeanSqErr=np.sqrt(metrics.mean_squared_error(y_test,y_pred_mlr))
print('R squared: {:.2f}'.format(mlr.score(x,y)*100))
print('Mean Absolute Error:',meanAbErr)
print('Mean Square Error:',meanSqrErr)
print('Root Mean Square Error:',rootMeanSqErr)
# Out:
# R squared: 79.78
# Mean Absolute Error: 696.7780499033014
# Mean Square Error: 827867.6145348792
# Root Mean Square Error: 909.8723067193985
